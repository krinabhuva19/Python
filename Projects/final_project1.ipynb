# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('expenses.csv', encoding= 'unicode_escape')

# %%
df.shape
# Out:
# (50, 4)

# %%
df.head
# Out:
# <bound method NDFrame.head of           Date  Amount       Category            Description
# 0   2026-01-01     248  Entertainment  Entertainment expense
# 1   2026-01-02     589      Transport      Transport expense
# 2   2026-01-03     200      Utilities      Utilities expense
# 3   2026-01-04     994      Utilities      Utilities expense
# 4   2026-01-05     886      Utilities      Utilities expense
# 5   2026-01-06     618           Food           Food expense
# 6   2026-01-07     668      Utilities      Utilities expense
# 7   2026-01-08    1710      Utilities      Utilities expense
# 8   2026-01-09     258       Shopping       Shopping expense
# 9   2026-01-10     464           Food           Food expense
# 10  2026-01-11     364      Transport      Transport expense
# 11  2026-01-12     784           Food           Food expense
# 12  2026-01-13     706  Entertainment  Entertainment expense
# 13  2026-01-14     907           Food           Food expense
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         50 non-null     str
#  1   Amount       50 non-null     int64
#  2   Category     50 non-null     str
#  3   Description  50 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.7 KB

# %%
print(df.columns)
# Out:
# Index(['Date', 'Amount', 'Category', 'Description'], dtype='str')

# %%
pd.isnull(df).sum()
# Out:
# Date           0
# Amount         0
# Category       0
# Description    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['Amount'] =df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['Date', 'Amount', 'Category', 'Description'], dtype='str')

# %%
df.describe()
# Out:
#             Amount
# count    50.000000
# mean    851.380000
# std     500.014689
# min      62.000000
# 25%     474.750000
# 50%     767.000000
# 75%    1250.750000
# max    1851.000000

# %%
df[['Amount','Category','Description']].describe()
# Out:
#             Amount
# count    50.000000
# mean    851.380000
# std     500.014689
# min      62.000000
# 25%     474.750000
# 50%     767.000000
# 75%    1250.750000
# max    1851.000000

# %%
ax = sns.countplot(x="Category", data=df)

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
sales_payment = df.groupby(['Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Category', y='Amount', data=sales_payment)

plt.title("Total Expense By Payment Mode")
plt.xlabel("Payment Mode")
plt.ylabel("Total Amount")

plt.show()

# %%
ax = sns.countplot(data=df, x='Category', hue='Category')

for bars in ax.containers:
    ax.bar_label(bars)

plt.title("Category Wise Payment Mode Count")
plt.xlabel("Category")
plt.ylabel("Count")

plt.show()

# %%
sales_category = df.groupby(['Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x='Category', y='Amount', data=sales_category)

plt.show()

# %%
sales_category = df.groupby(['Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(15,5)})

sns.barplot(data=sales_category, x='Category', y='Amount')

plt.show()

# %%
sales_category = df.groupby(['Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(15,5)})

sns.barplot(data=sales_category, x='Category', y='Amount')

plt.show()

# %%
sns.set(rc={'figure.figsize':(7,5)})

ax = sns.countplot(data=df, x='Category')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
sales_category = df.groupby(['Category', 'Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})

sns.barplot(data=sales_category, x='Category', y='Amount', hue='Category')

plt.show()

# %%
sns.set(rc={'figure.figsize':(20,5)})

ax = sns.countplot(data=df, x='Category')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
sales_category = df.groupby(['Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})

sns.barplot(data=sales_category, x='Category', y='Amount')

plt.show()

# %%
sns.set(rc={'figure.figsize':(20,5)})

ax = sns.countplot(data=df, x='Category')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
sales_category = df.groupby(['Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})

sns.barplot(data=sales_category, x='Category', y='Amount')

plt.show()

# %%
sales_category = df.groupby(['Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})

sns.barplot(data=sales_category, x='Category', y='Amount')

plt.show()

# %%
fig1, ax1 = plt.subplots(figsize=(12,7))

df.groupby('Category')['Amount'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')

plt.show()
